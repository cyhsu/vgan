# %%
import vgan

# %%
dh = vgan.getHYCOM_Local()

# %%
MissionList = vgan.checkDownloadList()
MissionList
# Out:
# ['ng314-20200806T2040', 'Stommel-20200813T1200', 'usf-gansett-20200813T1200']

# %%
mission = 'ng314-20200806T2040'
mission_status = vgan.getJson('mission_status.json')

PI = mission_status[mission]['PI']
TimeCoverageStart = mission_status[mission]['Time Coverage Start']
TimeCoverageEnd = mission_status[mission]['Time Coverage End']

# %%
app = vgan.view(mission, dh, OutHtmlPath='./test_{}_index.html'.format(mission))
app
# Out:
# {'PI': 'John Kerfoot', 'Institute': 'Rutgers University', 'Time Coverage Start': '2020-08-06T19:05:04Z', 'Time Coverage End': '2020-08-21T19:33:24Z', 'Data Path': './Data/Glider/Rutgers University/ng314-20200806T2040', 'LOGO Path': './static/img/logo/RutgersLogo.png', 'Status': 'Active'}
# ng314-20200806T2040 John Kerfoot 2020-08-06T19:05:04Z 2020-08-21T19:33:24Z
# /Users/cyhsu/miniconda3/envs/franke/lib/python3.6/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# /Users/cyhsu/miniconda3/envs/franke/lib/python3.6/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# ...

# %%
app
